# %% [markdown]
# # Churn Prediction Project.

# %% [markdown]
# ### Data preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/workspaces/Machine-Learning-Bootcamp-by-Zoomcamp/Week3/Telecom_churn_csv data.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerID              7590-VHVEG    5575-GNVDE      3668-QPYBK
# gender                      Female          Male            Male
# SeniorCitizen                    0             0               0
# Partner                        Yes            No              No
# Dependents                      No            No              No
# tenure                           1            34               2
# PhoneService                    No           Yes             Yes
# MultipleLines     No phone service            No              No
# InternetService                DSL           DSL             DSL
# OnlineSecurity                  No           Yes             Yes
# OnlineBackup                   Yes            No             Yes
# DeviceProtection                No           Yes              No
# TechSupport                     No            No              No
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ','_')

categorical_col = list(df.dtypes[df.dtypes == 'object'].index)

for col in categorical_col:

    df[col] = df[col].str.lower().str.replace(' ','_')

# %%
df.head().T
# Out:
#                                  0             1               2  \
# customerid              7590-vhveg    5575-gnvde      3668-qpybk
# gender                      female          male            male
# seniorcitizen                    0             0               0
# partner                        yes            no              no
# dependents                      no            no              no
# tenure                           1            34               2
# phoneservice                    no           yes             yes
# multiplelines     no_phone_service            no              no
# internetservice                dsl           dsl             dsl
# onlinesecurity                  no           yes             yes
# onlinebackup                   yes            no             yes
# deviceprotection                no           yes              no
# techsupport                     no            no              no
# ...

# %%
df.dtypes
# Out:
# customerid           object
# gender               object
# seniorcitizen         int64
# partner              object
# dependents           object
# tenure                int64
# phoneservice         object
# multiplelines        object
# internetservice      object
# onlinesecurity       object
# onlinebackup         object
# deviceprotection     object
# techsupport          object
# streamingtv          object
# streamingmovies      object
# contract             object
# paperlessbilling     object
# paymentmethod        object
# monthlycharges      float64
# totalcharges         object
# churn                object
# dtype: object

# %%
df['totalcharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: totalcharges, Length: 7043, dtype: object

# %%
tc = pd.to_numeric(df.totalcharges, errors = 'coerce')
df[tc.isnull()][['customerid','totalcharges']]
# Out:
#       customerid totalcharges
# 488   4472-lvygi            _
# 753   3115-czmzd            _
# 936   5709-lvoeq            _
# 1082  4367-nuyao            _
# 1340  1371-dwpaz            _
# 3331  7644-omvmy            _
# 3826  3213-vvolg            _
# 4380  2520-sgtta            _
# 5218  2923-arzlg            _
# 6670  4075-wkniu            _
# 6754  2775-sefee            _

# %%
df.totalcharges = df.totalcharges.fillna(0)

# %%
df.totalcharges.isna().sum()
# Out:
# np.int64(0)

# %%
df.churn.head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3     no
# 4    yes
# Name: churn, dtype: object

# %%
df.churn = (df.churn == 'yes').astype(int)

# %%
df.churn.nunique()
# Out:
# 2

# %% [markdown]
# ### Setting up the validation framework
#
# **perform the train/validation/test split with scikit-learn**

# %%
from sklearn.model_selection import train_test_split

# %%
full_train_df, test_df = train_test_split(df, test_size = 0.2, random_state = 1)

# %%
train_df, val_df = train_test_split(full_train_df, test_size = 0.25, random_state = 1)
assert len(df) == len(train_df) + len(test_df) + len(val_df)

# %%
len(train_df), len(val_df), len(test_df)
# Out:
# (4225, 1409, 1409)

# %%
train_df.head().T
# Out:
#                               3897              1980              6302  \
# customerid              8015-ihcgw        1960-uycnn        9250-wypll
# gender                      female              male            female
# seniorcitizen                    0                 0                 0
# partner                        yes                no                no
# dependents                     yes                no                no
# tenure                          72                10                 5
# phoneservice                   yes               yes               yes
# multiplelines                  yes               yes               yes
# internetservice        fiber_optic       fiber_optic       fiber_optic
# onlinesecurity                 yes                no                no
# onlinebackup                   yes               yes                no
# deviceprotection               yes               yes                no
# ...

# %%
train_df = train_df.reset_index(drop = True)
val_df = val_df.reset_index(drop = True)
test_df = test_df.reset_index(drop = True)

# %%
val_df
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 0     5846-neqvz    male              0     yes        yes      71
# 1     3645-deygf    male              0      no        yes       1
# 2     3590-tcxtb    male              0      no         no       1
# 3     8433-wxgna    male              0      no         no       2
# 4     2654-vbvpb  female              0      no         no       1
# ...          ...     ...            ...     ...        ...     ...
# 1404  0980-pvmrc  female              0     yes        yes      40
# 1405  2325-zusfd  female              0     yes        yes      57
# 1406  7382-dfjtu    male              0      no         no      18
# 1407  6521-yytyi    male              0      no        yes       1
# 1408  3049-solay  female              0     yes         no       3
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 0             yes                no             dsl                  yes  ...
# ...

# %% [markdown]
# **Extract our y variable**

# %%
y_train = train_df.churn.values
y_val = val_df.churn.values
y_test = test_df.churn.values

# %%
del train_df['churn']
del val_df['churn']
del test_df['churn']

# %% [markdown]
# ### EDA [Exploratory Data Analysis]

# %%
full_train_df = full_train_df.reset_index(drop = True)

# %%
full_train_df.isna().sum()
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
global_churn_rate = full_train_df.churn.mean()
global_churn_rate
# Out:
# np.float64(0.26996805111821087)

# %%
numeric_col = ['tenure', 'monthlycharges', 'totalcharges']

# %%
categorical = list(full_train_df.dtypes[full_train_df.dtypes == 'object'].index)

# %%
categorical.remove('totalcharges')

# %%
full_train_df[categorical].nunique()
# Out:
# gender              2
# partner             2
# dependents          2
# phoneservice        2
# multiplelines       3
# internetservice     3
# onlinesecurity      3
# onlinebackup        3
# deviceprotection    3
# techsupport         3
# streamingtv         3
# streamingmovies     3
# contract            3
# paperlessbilling    2
# paymentmethod       4
# seniorcitizen       2
# dtype: int64

# %% [markdown]
# ### feature importance: Churn rate and risk ratio
#
# Feature importance analysis is part of **(EDA)** identifying which feature affect our target variable .
#
# 1. churn rate
# 2. Risk Ratio
# 3. Mutual information later

# %% [markdown]
# **churn rate**

# %%
full_train_df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  5442-pptjy    male              0     yes        yes      12          yes
# 1  6261-rcvns  female              0      no         no      42          yes
# 2  2176-osjuv    male              0     yes         no      71          yes
# 3  6161-erdgd    male              0     yes        yes      71          yes
# 4  2364-ufrom    male              0      no         no      30          yes
#
#   multiplelines internetservice       onlinesecurity  ...  \
# 0            no              no  no_internet_service  ...
# 1            no             dsl                  yes  ...
# 2           yes             dsl                  yes  ...
# 3           yes             dsl                  yes  ...
# 4            no             dsl                  yes  ...
#
#       deviceprotection          techsupport          streamingtv  \
# 0  no_internet_service  no_internet_service  no_internet_service
# ...

# %%
churn_female = full_train_df[full_train_df['gender']=='female'].churn.mean()

# %%
churn_female
# Out:
# np.float64(0.27682403433476394)

# %%
churn_male = full_train_df[full_train_df['gender']=='male'].churn.mean()

churn_male
# Out:
# np.float64(0.2632135306553911)

# %%
global_churn_rate
# Out:
# churn
# 0    0.730032
# 1    0.269968
# Name: proportion, dtype: float64

# %%
# for partner variable

churn_partner = full_train_df[full_train_df['partner'] == 'yes'].churn.mean()
churn_no_partner = full_train_df[full_train_df['partner'] == 'no'].churn.mean()

# %%
churn_partner
# Out:
# np.float64(0.20503330866025166)

# %%
churn_no_partner
# Out:
# np.float64(0.3298090040927694)

# %%
global_churn = 0.269968

# %%
from IPython.display import display

# %%
for c in categorical:
    print(c)
    df_group = full_train_df.groupby(c).churn.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_churn
    df_group['risk'] = df_group['mean']/global_churn
    display(df_group)
    print()
    print()
# Out:
# customerid
#             mean  count      diff      risk
# customerid
# 0002-orfbo   0.0      1 -0.269968  0.000000
# 0004-tlhlj   1.0      1  0.730032  3.704143
# 0011-igkff   1.0      1  0.730032  3.704143
# 0013-exchz   1.0      1  0.730032  3.704143
# 0013-mhzwf   0.0      1 -0.269968  0.000000
# ...          ...    ...       ...       ...
# 9987-lutyd   0.0      1 -0.269968  0.000000
# 9992-rramn   1.0      1  0.730032  3.704143
# 9992-ujoel   0.0      1 -0.269968  0.000000
# 9993-lhieb   0.0      1 -0.269968  0.000000
# 9995-hotoh   0.0      1 -0.269968  0.000000
#
# [5634 rows x 4 columns]
# gender
#             mean  count      diff      risk
# gender
# female  0.276824   2796  0.006856  1.025396
# male    0.263214   2838 -0.006754  0.974980
# partner
#              mean  count      diff      risk
# partner
# no       0.329809   2932  0.059841  1.221660
# yes      0.205033   2702 -0.064935  0.759473
# dependents
#                 mean  count      diff      risk
# dependents
# ...

# %% [markdown]
# ### Feature Importance: Mutual information
#
# Mutual information - concept from information theory, it tells us how much we can learn about one variable if we know the value of another.

# %%
from sklearn.metrics import mutual_info_score

# %%
mutual_info_score(full_train_df.churn, full_train_df.contract)
# Out:
# np.float64(0.0983203874041556)

# %%
mutual_info_score(full_train_df.gender, full_train_df.churn)
# Out:
# np.float64(0.0001174846211139946)

# %%
def mutual_info_churn_score(series):

    return mutual_info_score(series, full_train_df.churn)

# %%
full_train_df[categorical].apply(mutual_info_churn_score)
# Out:
# customerid          0.583227
# gender              0.000117
# partner             0.009968
# dependents          0.012346
# phoneservice        0.000229
# multiplelines       0.000857
# internetservice     0.055868
# onlinesecurity      0.063085
# onlinebackup        0.046923
# deviceprotection    0.043453
# techsupport         0.061032
# streamingtv         0.031853
# streamingmovies     0.031581
# contract            0.098320
# paperlessbilling    0.017589
# paymentmethod       0.043210
# dtype: float64

# %% [markdown]
# ### Corelation Coeficient

# %%
full_train_df[numeric_col].corrwith(full_train_df.churn)
# Out:
# tenure           -0.351885
# monthlycharges    0.196805
# totalcharges     -0.196353
# dtype: float64

# %% [markdown]
# ### One-hot encoding
#
# **. Use scikit-learn to encode categorical features**

# %%
train_df.head()
# Out:
#    customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  8015-ihcgw  female              0     yes        yes      72          yes
# 1  1960-uycnn    male              0      no         no      10          yes
# 2  9250-wypll  female              0      no         no       5          yes
# 3  6786-obwqr  female              0     yes        yes       5          yes
# 4  1328-euzhc  female              0     yes         no      18          yes
#
#   multiplelines internetservice       onlinesecurity         onlinebackup  \
# 0           yes     fiber_optic                  yes                  yes
# 1           yes     fiber_optic                   no                  yes
# 2           yes     fiber_optic                   no                   no
# 3            no     fiber_optic                   no                   no
# 4            no              no  no_internet_service  no_internet_service
#
# ...

# %%
from sklearn.feature_extraction import

# %%
del categorical[0]

# %%
categorical.append('seniorcitizen')

# %%
categorical
# Out:
# ['gender',
#  'partner',
#  'dependents',
#  'phoneservice',
#  'multiplelines',
#  'internetservice',
#  'onlinesecurity',
#  'onlinebackup',
#  'deviceprotection',
#  'techsupport',
#  'streamingtv',
#  'streamingmovies',
#  'contract',
#  'paperlessbilling',
#  'paymentmethod',
#  'seniorcitizen']

# %%
train_dict = train_df[categorical + numeric_col].to_dict(orient = 'records' )

# %%
train_dict[1]
# Out:
# {'gender': 'male',
#  'partner': 'no',
#  'dependents': 'no',
#  'phoneservice': 'yes',
#  'multiplelines': 'yes',
#  'internetservice': 'fiber_optic',
#  'onlinesecurity': 'no',
#  'onlinebackup': 'yes',
#  'deviceprotection': 'yes',
#  'techsupport': 'no',
#  'streamingtv': 'no',
#  'streamingmovies': 'yes',
#  'contract': 'month-to-month',
#  'paperlessbilling': 'yes',
#  'paymentmethod': 'electronic_check',
#  'seniorcitizen': 0,
#  'tenure': 10,
#  'monthlycharges': 95.25,
#  'totalcharges': 1021.55}

# %%
dv = DictVectorizer(sparse=False)

# %%
dv.fit(train_dict)
# Out:
# DictVectorizer(sparse=False)

# %%
dv.get_feature_names_out()
# Out:
# array(['contract=month-to-month', 'contract=one_year',
#        'contract=two_year', 'dependents=no', 'dependents=yes',
#        'deviceprotection=no', 'deviceprotection=no_internet_service',
#        'deviceprotection=yes', 'gender=female', 'gender=male',
#        'internetservice=dsl', 'internetservice=fiber_optic',
#        'internetservice=no', 'monthlycharges', 'multiplelines=no',
#        'multiplelines=no_phone_service', 'multiplelines=yes',
#        'onlinebackup=no', 'onlinebackup=no_internet_service',
#        'onlinebackup=yes', 'onlinesecurity=no',
#        'onlinesecurity=no_internet_service', 'onlinesecurity=yes',
#        'paperlessbilling=no', 'paperlessbilling=yes', 'partner=no',
#        'partner=yes', 'paymentmethod=bank_transfer_(automatic)',
#        'paymentmethod=credit_card_(automatic)',
#        'paymentmethod=electronic_check', 'paymentmethod=mailed_check',
#        'phoneservice=no', 'phoneservice=yes', 'seniorcitizen',
# ...

# %%
X_train = dv.transform(train_dict)

# %%
val_dict = val_df[categorical + numeric_col].to_dict(orient = 'records' )

# %%
X_val = dv.fit_transform(val_dict)

# %%
test_dict = test_df[categorical + numeric_col].to_dict(orient = 'records' )

# %%
X_test = dv.fit_transform(test_dict)

# %% [markdown]
# ### Logistics Regression
